# %%
from tblnflgame_dao import get_rows

# %%
data = get_rows()
# Out:
# HERE
# CLOSED

# %%
data_nwe = data.loc[(data['team_key'] == 'nwe')]

# %%
data.groupby(['team', 'season'])['yards_off', 'pass_yds_off', 'rush_yds_off', 'to_off', 'first_down_def', 'yards_def', 'pass_yds_def', 'rush_yds_def', 'to_def'].sum().reset_index()
# Out:
# /home/ccorbo/venv/lib/python3.6/site-packages/ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.
#                     team  season  yards_off  pass_yds_off  rush_yds_off  \
# 0      Arizona Cardinals    2019       5467          3477          1990
# 1        Atlanta Falcons    2019       6075          4714          1361
# 2       Baltimore Ravens    2019       7051          3570          3481
# 3          Buffalo Bills    2019       5708          3482          2226
# 4      Carolina Panthers    2019       5469          3650          1819
# 5          Chicago Bears    2019       4749          3291          1458
# 6     Cincinnati Bengals    2019       5169          3652          1517
# 7       Cleveland Browns    2019       5455          3554          1901
# 8         Dallas Cowboys    2019       6904          4751          2153
# ...
